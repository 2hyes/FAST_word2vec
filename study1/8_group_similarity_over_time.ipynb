# %%
# !pip install pingouin 
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, http://3.34.149.105:2502/simple/
# Requirement already satisfied: pingouin in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.19 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.26.0)
# Requirement already satisfied: scipy>=1.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.11.2)
# Requirement already satisfied: pandas>=1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (2.1.0)
# Requirement already satisfied: matplotlib>=3.0.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (3.8.0)
# Requirement already satisfied: seaborn>=0.11 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.13.0)
# Requirement already satisfied: statsmodels>=0.13 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.14.0)
# Requirement already satisfied: scikit-learn in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.3.1)
# Requirement already satisfied: pandas-flavor>=0.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.6.0)
# Requirement already satisfied: outdated in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.2.2)
# Requirement already satisfied: tabulate in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.0->pingouin) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.0->pingouin) (2023.3)
# Requirement already satisfied: xarray in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas-flavor>=0.2.0->pingouin) (2023.10.1)
# Requirement already satisfied: patsy>=0.5.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from statsmodels>=0.13->pingouin) (0.5.3)
# Requirement already satisfied: setuptools>=44 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (58.1.0)
# Requirement already satisfied: littleutils in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (0.2.2)
# Requirement already satisfied: requests in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (2.31.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from scikit-learn->pingouin) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from scikit-learn->pingouin) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.2->pingouin) (3.17.0)
# Requirement already satisfied: six in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13->pingouin) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (2023.7.22)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, http://3.34.149.105:2502/simple/
# Requirement already satisfied: seaborn in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
import os
import platform

import pandas as pd
import numpy as np
from gensim.models import KeyedVectors
from pingouin import ancova
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multitest import multipletests
from scipy.interpolate import interp1d

# %%
import warnings

# RuntimeWarning 무시
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os_system = platform.system() # 맥북은 Darwin, 윈도우는 Windows

# 현재 프로젝트 폴더 위치 지정. os.getcwd()는 지금 코드 실행하는 현 위치를 출력해줍니다.
study1_dir = os.getcwd()
model_path = '\\..\\pretrained\\GoogleNews-vectors-negative300.bin' if os_system == 'Windows' else '/../pretrained/GoogleNews-vectors-negative300.bin'

# data/processed 폴더 위치 지정
processed_data_dir = study1_dir + ('\\data\\processed\\' if os_system == 'Windows' else '/data/processed/')

# boxplots 이미지 저장할 폴더 위치 지정
graph_image_dir = study1_dir + ('\\graph\\ancova_boxplots\\' if os_system == 'Windows' else '/graph/ancova_boxplots/')
# 폴더 없으면 생성
os.makedirs(graph_image_dir, exist_ok=True)

# %%
# 테이블 읽어오기
similarity_data = pd.read_csv(processed_data_dir + 'similarity_coherence.csv', encoding='ISO-8859-1')
survey_data = pd.read_csv(processed_data_dir + 'survey_data.csv', encoding='ISO-8859-1')

survey_data.drop([210], axis=0, inplace=True) # NaN

# Age 정수형으로 형변환
survey_data['age'] = survey_data['age'].astype(int)

# %% [markdown]
# ## 그룹간 cosine similarity의 시행별 추이의 차이
# ### moving window적용

# %%
def calculate_moving_average(data, window_size=8, moving_size=4):
    moving_average_data = pd.DataFrame()
    index=1
    for i in range(0, len(data.columns) - window_size + 1, moving_size):
        window_data = data.iloc[:, i:i + window_size]
        window_mean = window_data.mean(axis=1) 
        moving_average_data[f'{index}'] = window_mean
        index += 1

    return moving_average_data

# %% [markdown]
# ### ANCOVA

# %%
def analyze_ancova_for_each_column(data, column_len: int, between: str, covar: list):
    significant_0_05 = [] # p<0.5
    significant_0_01 = [] # p<0.1
    significant_0_001 = [] # p<0.01
    p_values = []
    
    # 각 열(1에서 27까지)에 대한 ANCOVA 실행
    for column_number in range(1, column_len):
        ancova_result = ancova(data=data, dv=f'{column_number}', between=between, covar=covar)
        p_value = ancova_result['p-unc'][0]
        p_values.append((int(column_number), ancova_result['p-unc'][0]))

        print(f"Column {column_number} ANCOVA Results:")
        print(ancova_result)
        print()

        if p_value < 0.05:
            significant_0_05.append(column_number)
        if p_value < 0.01:
            significant_0_01.append(column_number)
        if p_value < 0.001:
            significant_0_001.append(column_number)

    return p_values, significant_0_05, significant_0_01, significant_0_001

# %% [markdown]
# ### similairty line graph

# %%
def draw_similarity_line_graph(data, target_columns: list, significant_list: list, window_size: int, seed_word: str, filename: str, ax=None):
    low = data.loc[data['group_PA'] == 1].iloc[:, :len(target_columns)]
    high = data.loc[data['group_PA'] == 2].iloc[:, :len(target_columns)]

    low_datas = low.mean()
    high_datas = high.mean()

    plt.figure(figsize=(8, 6))
    plt.plot(high_datas, marker='.', color='#7a58a3', linestyle='-', label='High')
    plt.plot(low_datas, marker='.', color='#73a69e', linestyle='--', label='low')

    # 유의한 점 표시
    for point in significant_list:
        plt.axvspan(point - 1.5, point - 0.5, alpha=0.2, color='gray')
        # *: 여기 point-1.05, y_high_interp[point-1] + "실수"부분으로 조정 가능
        plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3')
        
    plt.title(f'Seed word: {seed_word}', fontsize=15, weight='bold')
    plt.ylim(0, 0.2)
    plt.legend(loc='upper right')
    # plt.xticks(range(0, len(low_datas), window_size))

    filepath = filepath = os.path.join(graph_image_dir, filename)
    plt.savefig(filepath, dpi=300)

    # plt.show()

# %% [markdown]
# ### similairty smoothing graph

# %%
def draw_similarity_smoothing_graph(data, target_columns: list, significant_list: list, window_size: int, seed_word:str, filename: str):
    def interpolate_data(values, interpolation_interval=0.1):
        x = np.arange(0, len(values))
        x_interp = np.arange(0, len(values), interpolation_interval)

        interpolation_function = interp1d(x, values, kind='quadratic', fill_value='extrapolate')
        y_interp = interpolation_function(x_interp)
        
        return x_interp, y_interp

    
    low = data.loc[data['group_PA'] == 1].iloc[:, :len(target_columns)]
    high = data.loc[data['group_PA'] == 2].iloc[:, :len(target_columns)]

    low_datas = low.mean()
    high_datas = high.mean()

    # low 및 high 데이터 모두 보간
    x_low_interp, y_low_interp = interpolate_data(low_datas.values, interpolation_interval=0.1)
    x_high_interp, y_high_interp = interpolate_data(high_datas.values, interpolation_interval=0.1)
    # 보간 된 데이터의 표준 오차 계산
    low_sem_interp = y_low_interp.std(axis=0, ddof=1) / np.sqrt(len(x_low_interp)) if y_low_interp.std(axis=0, ddof=1) != 0 else 1.0 / np.sqrt(len(x_low_interp))
    high_sem_interp = y_high_interp.std(axis=0, ddof=1) / np.sqrt(len(x_high_interp)) if y_high_interp.std(axis=0, ddof=1) != 0 else 1.0 / np.sqrt(len(x_high_interp))

    # 원래 데이터에 대한 신뢰 구간 계산
    confidence_interval = 1.96  # 95% 신뢰 구간
    lower_bound_low = y_low_interp - confidence_interval * low_sem_interp
    upper_bound_low = y_low_interp + confidence_interval * low_sem_interp
    lower_bound_high = y_high_interp - confidence_interval * high_sem_interp
    upper_bound_high = y_high_interp + confidence_interval * high_sem_interp


    plt.figure(figsize=(8, 6))

    #  신뢰구간 색칠
    plt.fill_between(x_low_interp, lower_bound_low, upper_bound_low, color='#73a69e', alpha=0.3)
    plt.fill_between(x_high_interp, lower_bound_high, upper_bound_high, color='#7a58a3', alpha=0.3)

    # 스무딩 그래프
    plt.plot(x_high_interp, y_high_interp, color='#7a58a3', linestyle='-', label='High')
    plt.plot(x_low_interp, y_low_interp, color='#73a69e', linestyle='--', label='Low')

    # 유의한 점 표시
    for point in significant_list:
        plt.axvspan(point - 1.5, point - 0.5, alpha=0.2, color='gray')
        # *: 여기 point-1.05, y_high_interp[point-1] + "실수"부분으로 조정 가능
        plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3') 

    plt.title(f'Seed word: {seed_word}', fontsize=15, weight='bold')
    plt.ylim(0, 0.2)
    plt.legend(loc='upper right')
    # plt.xticks(range(0, len(low_smoothed_values), window_size))

    filepath = filepath = os.path.join(graph_image_dir, filename)
    plt.savefig(filepath, dpi=300)

    # plt.show()

# %% [markdown]
# ## multiple comparison

# %%
def benjamini_hochberg_correction(p_values, alpha=0.05):
    fdr_significant_0_05 = [] # p<0.5
    fdr_significant_0_01 = [] # p<0.1
    fdr_significant_0_001 = [] # p<0.01

    p_values = [item[1] for item in p_values]
    adjusted_p_values = multipletests(p_values, method='fdr_bh', alpha=alpha)[1]

    for i, p_value in enumerate(adjusted_p_values):
        if p_value < 0.05:
            fdr_significant_0_05.append(i+1)
        if p_value < 0.01:
            fdr_significant_0_01.append(i+1)
        if p_value < 0.001:
            fdr_significant_0_001.append(i+1)

    return adjusted_p_values, fdr_significant_0_05, fdr_significant_0_01, fdr_significant_0_001

# %% [markdown]
# # main code

# %%
seed_words = ['key', 'money', 'friend']
target_words = ['money', 'friend']

# %%
similarity_datas = {
    'key_money': similarity_data.iloc[:, 1:31],
    'money_money': similarity_data.iloc[:, 31:61],
    'friend_money': similarity_data.iloc[:, 61:91],

    'key_friend': similarity_data.iloc[:, 91:121],
    'money_friend': similarity_data.iloc[:, 121:151],
    'friend_friend': similarity_data.iloc[:, 151:181]
}

# %%
window_size=6
moving_size=3

for i, seed in enumerate(seed_words): 
    for j, target in enumerate(target_words): 
        print(f'Seed word: {seed}, Target: {target}')
        data = similarity_datas[f'{seed}_{target}']

        moving_average_df = calculate_moving_average(data=data,
                                                     window_size=window_size,
                                                     moving_size=moving_size)
        # ancova 분석을 위해 데이터 연결
        merged_df = pd.concat([moving_average_df, survey_data], axis=1)

        target_columns = moving_average_df.columns
        # ancova 분석 -> 결과: p값들, significant한 index정보
        p_values, significant_0_05, significant_0_01, significant_0_001 = analyze_ancova_for_each_column(data=merged_df,
                                                                                                         column_len=len(target_columns),
                                                                                                         between='group_PA',
                                                                                                         covar=['age', 'sex'])

        # line graph, smoothing graph 그리기
        draw_similarity_line_graph(data=merged_df,
                                   target_columns=target_columns,
                                   significant_list=significant_0_05,
                                   window_size=window_size,
                                   seed_word=seed,
                                   filename=f'line_graph_{seed}_{target}_ma{moving_size}_w{window_size}.png')
        draw_similarity_smoothing_graph(data=merged_df,
                                        target_columns=target_columns,
                                        significant_list=significant_0_05,
                                        window_size=window_size,
                                        seed_word=seed,
                                        filename=f'smoothing_graph_{seed}_{target}_ma{moving_size}_w{window_size}.png')

        # multiple comparison 보정
        adjusted_p_values, fdr_significant_0_05, fdr_significant_0_01, fdr_significant_0_001 = benjamini_hochberg_correction(p_values=p_values, alpha=0.05)
        print(f'보정 전 p-values: {[item[1] for item in p_values]}')
        print(f'보정 후 p-values: {adjusted_p_values}')
        print()
        print()
# Out:
# Seed word: key, Target: money
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002352    1  1.115827  0.292056  0.005387
# 1       age  0.002599    1  1.233179  0.268084  0.005951
# 2       sex  0.001507    1  0.715059  0.398750  0.003459
# 3  Residual  0.434199  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002973    1  1.026628  0.312141  0.004959
# 1       age  0.003258    1  1.125201  0.290043  0.005432
# 2       sex  0.005084    1  1.755752  0.186623  0.008451
# 3  Residual  0.596522  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000209    1  0.111234  0.739083  0.000540
# 1       age  0.000001    1  0.000565  0.981065  0.000003
# 2       sex  0.003078    1  1.637610  0.202093  0.007887
# 3  Residual  0.387145  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001355    1  0.596441  0.440824  0.002887
# 1       age  0.001738    1  0.764764  0.382860  0.003699
# 2       sex  0.000971    1  0.427208  0.514091  0.002070
# 3  Residual  0.468124  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000051    1  0.022150  0.881835  0.000108
# 1       age  0.001252    1  0.539691  0.463396  0.002613
# 2       sex  0.000650    1  0.280284  0.597085  0.001359
# 3  Residual  0.477966  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000652    1  0.351827  0.553731  0.001705
# 1       age  0.000219    1  0.118432  0.731092  0.000575
# 2       sex  0.000258    1  0.139385  0.709277  0.000676
# 3  Residual  0.381558  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000449    1  0.173396  0.677545  0.000841
# 1       age  0.000118    1  0.045533  0.831238  0.000221
# 2       sex  0.000294    1  0.113441  0.736603  0.000550
# 3  Residual  0.533507  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000014    1  0.005972  0.938475  0.000029
# 1       age  0.000114    1  0.047024  0.828540  0.000228
# 2       sex  0.001273    1  0.524799  0.469624  0.002541
# 3  Residual  0.499742  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.2920559447647275, 0.3121406643195866, 0.7390827211886426, 0.4408243495951085, 0.8818350832652984, 0.5537312945897785, 0.6775446846204467, 0.9384754868254068]
# 보정 후 p-values: [0.93847549 0.93847549 0.93847549 0.93847549 0.93847549 0.93847549
#  0.93847549 0.93847549]
#
#
# Seed word: key, Target: friend
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000142    1  0.029778  0.863164  0.000145
# 1       age  0.002387    1  0.502320  0.479284  0.002433
# 2       sex  0.006337    1  1.333307  0.249555  0.006431
# 3  Residual  0.979059  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002588    1  0.491467  0.484065  0.002380
# 1       age  0.000076    1  0.014435  0.904486  0.000070
# 2       sex  0.000292    1  0.055474  0.814031  0.000269
# 3  Residual  1.084926  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000007    1  0.001741  0.966756  0.000008
# 1       age  0.005548    1  1.372589  0.242721  0.006619
# 2       sex  0.005661    1  1.400709  0.237969  0.006754
# 3  Residual  0.832610  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003438    1  1.066831  0.302874  0.005152
# 1       age  0.006133    1  1.903076  0.169230  0.009154
# 2       sex  0.004648    1  1.442339  0.231140  0.006953
# 3  Residual  0.663881  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000842    1  0.203501  0.652384  0.000987
# 1       age  0.008019    1  1.937912  0.165396  0.009320
# 2       sex  0.000939    1  0.226982  0.634276  0.001101
# 3  Residual  0.852414  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source            SS   DF         F     p-unc           np2
# 0  group_PA  1.655469e-07    1  0.000036  0.995241  1.731218e-07
# 1       age  7.056328e-03    1  1.520116  0.219007  7.325149e-03
# 2       sex  2.874960e-03    1  0.619341  0.432197  2.997496e-03
# 3  Residual  9.562454e-01  206       NaN       NaN           NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000003    1  0.000619  0.980177  0.000003
# 1       age  0.001040    1  0.219761  0.639718  0.001066
# 2       sex  0.003959    1  0.836296  0.361527  0.004043
# 3  Residual  0.975102  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000469    1  0.108991  0.741631  0.000529
# 1       age  0.000082    1  0.019182  0.889983  0.000093
# 2       sex  0.000062    1  0.014398  0.904607  0.000070
# 3  Residual  0.885935  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.8631644528742614, 0.4840646738090727, 0.9667560551237384, 0.3028735147728716, 0.6523839030552672, 0.9952409538657705, 0.9801773910881173, 0.7416308242251081]
# 보정 후 p-values: [0.99524095 0.99524095 0.99524095 0.99524095 0.99524095 0.99524095
#  0.99524095 0.99524095]
#
#
# Seed word: money, Target: money
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000179    1  0.039967  0.841742  0.000194
# 1       age  0.007374    1  1.649162  0.200515  0.007942
# 2       sex  0.002669    1  0.596960  0.440626  0.002889
# 3  Residual  0.921083  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000735    1  0.237501  0.626535  0.001152
# 1       age  0.004959    1  1.601632  0.207102  0.007715
# 2       sex  0.000056    1  0.017941  0.893578  0.000087
# 3  Residual  0.637821  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000262    1  0.074809  0.784733  0.000363
# 1       age  0.002178    1  0.620799  0.431656  0.003005
# 2       sex  0.000302    1  0.086058  0.769546  0.000418
# 3  Residual  0.722637  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000822    1  0.231910  0.630622  0.001125
# 1       age  0.003954    1  1.114737  0.292291  0.005382
# 2       sex  0.004986    1  1.405943  0.237097  0.006779
# 3  Residual  0.730605  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.005160    1  2.078358  0.150919  0.009988
# 1       age  0.010388    1  4.184338  0.042070  0.019908
# 2       sex  0.008684    1  3.498006  0.062861  0.016697
# 3  Residual  0.511404  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001967    1  1.187479  0.277112  0.005731
# 1       age  0.004356    1  2.629571  0.106420  0.012604
# 2       sex  0.001777    1  1.073063  0.301469  0.005182
# 3  Residual  0.341232  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000681    1  0.393182  0.531326  0.001905
# 1       age  0.000059    1  0.034279  0.853296  0.000166
# 2       sex  0.000011    1  0.006083  0.937910  0.000030
# 3  Residual  0.356748  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001628    1  0.673292  0.412855  0.003258
# 1       age  0.001009    1  0.417314  0.518999  0.002022
# 2       sex  0.001755    1  0.725878  0.395212  0.003511
# 3  Residual  0.498175  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.8417415233118739, 0.6265347176206227, 0.7847330092225793, 0.6306221913618542, 0.150919284640105, 0.27711170938019203, 0.5313256050976953, 0.41285473679578655]
# 보정 후 p-values: [0.84174152 0.84082959 0.84174152 0.84082959 0.84082959 0.84082959
#  0.84082959 0.84082959]
#
#
# Seed word: money, Target: friend
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000483    1  0.196476  0.658045  0.000953
# 1       age  0.000494    1  0.200848  0.654508  0.000974
# 2       sex  0.000139    1  0.056499  0.812354  0.000274
# 3  Residual  0.506903  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.005617    1  1.582342  0.209848  0.007623
# 1       age  0.012688    1  3.574105  0.060091  0.017054
# 2       sex  0.005252    1  1.479390  0.225262  0.007130
# 3  Residual  0.731269  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.011586    1  2.662177  0.104288  0.012758
# 1       age  0.029643    1  6.811248  0.009723  0.032006
# 2       sex  0.003285    1  0.754872  0.385949  0.003651
# 3  Residual  0.896528  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000214    1  0.058395  0.809291  0.000283
# 1       age  0.000280    1  0.076231  0.782748  0.000370
# 2       sex  0.000040    1  0.010796  0.917346  0.000052
# 3  Residual  0.755358  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000026    1  0.006046  0.938099  0.000029
# 1       age  0.000084    1  0.019649  0.888657  0.000095
# 2       sex  0.001884    1  0.438518  0.508579  0.002124
# 3  Residual  0.884878  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.011006    1  2.432293  0.120394  0.011669
# 1       age  0.006659    1  1.471499  0.226499  0.007093
# 2       sex  0.002635    1  0.582315  0.446279  0.002819
# 3  Residual  0.932173  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.019103    1  4.544217  0.034215  0.021583
# 1       age  0.004177    1  0.993510  0.320055  0.004800
# 2       sex  0.000072    1  0.017120  0.896028  0.000083
# 3  Residual  0.865987  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.006933    1  1.687840  0.195338  0.008127
# 1       age  0.001570    1  0.382205  0.537109  0.001852
# 2       sex  0.003956    1  0.963026  0.327577  0.004653
# 3  Residual  0.846193  206       NaN       NaN       NaN
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_42529/1755704968.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3')
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_42529/1582272202.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3')
# 보정 전 p-values: [0.6580453415335217, 0.20984761397033153, 0.10428779767726194, 0.8092905302043113, 0.9380989092645884, 0.12039384337782923, 0.034214678802630315, 0.1953380989997043]
# 보정 후 p-values: [0.87739379 0.33575618 0.32105025 0.92490346 0.93809891 0.32105025
#  0.27371743 0.33575618]
#
#
# Seed word: friend, Target: money
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001902    1  0.592587  0.442302  0.002868
# 1       age  0.000052    1  0.016147  0.899007  0.000078
# 2       sex  0.002490    1  0.775623  0.379509  0.003751
# 3  Residual  0.661230  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003153    1  1.495251  0.222801  0.007206
# 1       age  0.000149    1  0.070710  0.790572  0.000343
# 2       sex  0.012548    1  5.951153  0.015554  0.028078
# 3  Residual  0.434342  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.008323    1  3.133233  0.078191  0.014982
# 1       age  0.000257    1  0.096721  0.756115  0.000469
# 2       sex  0.007070    1  2.661574  0.104327  0.012755
# 3  Residual  0.547220  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.006405    1  2.497207  0.115583  0.011977
# 1       age  0.000901    1  0.351280  0.554039  0.001702
# 2       sex  0.004301    1  1.676705  0.196812  0.008074
# 3  Residual  0.528388  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000921    1  0.440725  0.507515  0.002135
# 1       age  0.001333    1  0.637955  0.425372  0.003087
# 2       sex  0.000103    1  0.049461  0.824224  0.000240
# 3  Residual  0.430470  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000265    1  0.116490  0.733220  0.000565
# 1       age  0.000946    1  0.416519  0.519397  0.002018
# 2       sex  0.000010    1  0.004226  0.948230  0.000021
# 3  Residual  0.467800  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source            SS   DF         F     p-unc           np2
# 0  group_PA  3.757341e-04    1  0.111199  0.739122  5.395099e-04
# 1       age  1.026762e-03    1  0.303872  0.582063  1.472933e-03
# 2       sex  1.437345e-07    1  0.000043  0.994802  2.064971e-07
# 3  Residual  6.960602e-01  206       NaN       NaN           NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.004303    1  1.469295  0.226845  0.007082
# 1       age  0.000151    1  0.051484  0.820726  0.000250
# 2       sex  0.001711    1  0.584147  0.445566  0.002828
# 3  Residual  0.603350  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.4423023893160216, 0.2228006417238585, 0.07819065679079337, 0.11558257628784288, 0.5075151716889378, 0.7332204860607319, 0.7391223336106334, 0.22684543511476715]
# 보정 후 p-values: [0.6766869  0.45369087 0.45369087 0.45369087 0.6766869  0.73912233
#  0.73912233 0.45369087]
#
#
# Seed word: friend, Target: friend
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003849    1  0.453186  0.501580  0.002195
# 1       age  0.000157    1  0.018532  0.891848  0.000090
# 2       sex  0.017250    1  2.030881  0.155645  0.009762
# 3  Residual  1.749727  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003531    1  0.716015  0.398436  0.003464
# 1       age  0.001437    1  0.291476  0.589859  0.001413
# 2       sex  0.022280    1  4.518275  0.034726  0.021463
# 3  Residual  1.015802  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.014734    1  3.796690  0.052712  0.018097
# 1       age  0.006310    1  1.625995  0.203694  0.007831
# 2       sex  0.016298    1  4.199656  0.041700  0.019979
# 3  Residual  0.799457  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.023175    1  6.459746  0.011770  0.030405
# 1       age  0.003420    1  0.953165  0.330060  0.004606
# 2       sex  0.009169    1  2.555740  0.111427  0.012254
# 3  Residual  0.739051  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.010174    1  2.934669  0.088201  0.014046
# 1       age  0.002069    1  0.596933  0.440636  0.002889
# 2       sex  0.005697    1  1.643306  0.201313  0.007914
# 3  Residual  0.714172  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003121    1  0.921696  0.338156  0.004454
# 1       age  0.000535    1  0.158078  0.691344  0.000767
# 2       sex  0.000438    1  0.129479  0.719342  0.000628
# 3  Residual  0.697436  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001919    1  0.736785  0.391690  0.003564
# 1       age  0.001459    1  0.560312  0.454988  0.002713
# 2       sex  0.000200    1  0.076769  0.782002  0.000373
# 3  Residual  0.536456  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.008493    1  3.064998  0.081484  0.014661
# 1       age  0.005073    1  1.830652  0.177534  0.008808
# 2       sex  0.001808    1  0.652382  0.420194  0.003157
# 3  Residual  0.570818  206       NaN       NaN       NaN
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_42529/1755704968.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3')
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_42529/1582272202.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.05, high_datas[point-1] + 0.005, '*', fontsize=10, color='#7a58a3')
# 보정 전 p-values: [0.5015803031714545, 0.3984361005747735, 0.05271218916585027, 0.011770249043322186, 0.08820091442941015, 0.3381555207586886, 0.39169035663693885, 0.0814838270602401]
# 보정 후 p-values: [0.5015803  0.45535554 0.17640183 0.09416199 0.17640183 0.45535554
#  0.45535554 0.17640183]

# %% [markdown]
# #### target별로 3개씩 그래프 합치기

# %%
# 그리려고하는 window사이즈를 여기서 지정해도 되지만, 위에서 이미 지정되어있으므로 따로 하지않아도 됩니다.
# window_size=4
# moving_size=1

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axes = plt.subplots(2, 3, figsize=(24, 12), constrained_layout=True)
plt.subplots_adjust(top=0, wspace=0, hspace=0)
ax = axes.flatten()

i = 0
for target in target_words:
    for seed in seed_words:
        # 이미지 불러오기
        img = mpimg.imread(graph_image_dir + f'line_graph_{seed}_{target}_ma{moving_size}_w{window_size}.png')
        
        ax[i].imshow(img)
        ax[i].axis('off')

        if i in [0, 3]: 
            ax[i].text(0.03, 0.5, f'Similarity with "{target}"', transform=ax[i].transAxes, rotation=90, fontsize=15, color='black',  weight='bold', ha='center', va='center')

        i += 1
# 전체 그리드 이미지를 저장
filepath = os.path.join(graph_image_dir, f'all_similarity_line_graph_ma{moving_size}_w{window_size}.png' )
plt.savefig(filepath, dpi=300)

# 화면에 그리드 이미지 표시
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(24, 12), constrained_layout=True)
plt.subplots_adjust(top=0, wspace=0, hspace=0)

ax = axes.flatten()

i = 0
for target in target_words:
    for seed in seed_words:
        # 이미지 불러오기
        img = mpimg.imread(graph_image_dir + f'smoothing_graph_{seed}_{target}_ma{moving_size}_w{window_size}.png')
        
        ax[i].imshow(img)
        ax[i].axis('off')

        if i in [0, 3]: 
            ax[i].text(0.03, 0.5, f'Similarity with "{target}"', transform=ax[i].transAxes, rotation=90, fontsize=15, color='black',  weight='bold', ha='center', va='center')

        i += 1
# 전체 그리드 이미지를 저장

filepath = os.path.join(graph_image_dir, f'all_smoothing_line_graph_ma{moving_size}_w{window_size}.png')
plt.savefig(filepath, dpi=300)

# 화면에 그리드 이미지 표시
plt.show()
