# %%
# !pip install pingouin 
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, http://3.34.149.105:2502/simple/
# Requirement already satisfied: pingouin in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.19 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.26.0)
# Requirement already satisfied: scipy>=1.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.11.2)
# Requirement already satisfied: pandas>=1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (2.1.0)
# Requirement already satisfied: matplotlib>=3.0.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (3.8.0)
# Requirement already satisfied: seaborn>=0.11 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.13.0)
# Requirement already satisfied: statsmodels>=0.13 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.14.0)
# Requirement already satisfied: scikit-learn in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (1.3.1)
# Requirement already satisfied: pandas-flavor>=0.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.6.0)
# Requirement already satisfied: outdated in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.2.2)
# Requirement already satisfied: tabulate in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.0->pingouin) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.0->pingouin) (2023.3)
# Requirement already satisfied: xarray in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas-flavor>=0.2.0->pingouin) (2023.10.1)
# Requirement already satisfied: patsy>=0.5.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from statsmodels>=0.13->pingouin) (0.5.3)
# Requirement already satisfied: setuptools>=44 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (58.1.0)
# Requirement already satisfied: littleutils in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (0.2.2)
# Requirement already satisfied: requests in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from outdated->pingouin) (2.31.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from scikit-learn->pingouin) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from scikit-learn->pingouin) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.2->pingouin) (3.17.0)
# Requirement already satisfied: six in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13->pingouin) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from requests->outdated->pingouin) (2023.7.22)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, http://3.34.149.105:2502/simple/
# Requirement already satisfied: seaborn in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.3->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/ihyeseung/.pyenv/versions/3.9.17/envs/research/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
import os
import platform

import pandas as pd
import numpy as np
from gensim.models import KeyedVectors
from pingouin import ancova
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multitest import multipletests

# %%
import warnings

# RuntimeWarning 무시
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os_system = platform.system() # 맥북은 Darwin, 윈도우는 Windows

# 현재 프로젝트 폴더 위치 지정. os.getcwd()는 지금 코드 실행하는 현 위치를 출력해줍니다.
study1_dir = os.getcwd()
model_path = '\\..\\pretrained\\GoogleNews-vectors-negative300.bin' if os_system == 'Windows' else '/../pretrained/GoogleNews-vectors-negative300.bin'

# data/processed 폴더 위치 지정
processed_data_dir = study1_dir + ('\\data\\processed\\' if os_system == 'Windows' else '/data/processed/')

# boxplots 이미지 저장할 폴더 위치 지정
graph_image_dir = study1_dir + ('\\graph\\ancova_boxplots\\' if os_system == 'Windows' else '/graph/ancova_boxplots/')
# 폴더 없으면 생성
os.makedirs(graph_image_dir, exist_ok=True)

# %%
# 테이블 읽어오기
similarity_data = pd.read_csv(processed_data_dir + 'similarity_coherence.csv', encoding='ISO-8859-1')
survey_data = pd.read_csv(processed_data_dir + 'survey_data.csv', encoding='ISO-8859-1')

survey_data.drop([210], axis=0, inplace=True) # NaN

# Age 정수형으로 형변환
survey_data['age'] = survey_data['age'].astype(int)

# %% [markdown]
# ## 그룹간 cosine similarity의 시행별 추이의 차이
# ### moving window적용

# %%
def calculate_moving_average(data, window_size=8, moving_size=4):
    moving_average_data = pd.DataFrame()
    index=1
    for i in range(0, len(data.columns) - window_size + 1, moving_size):
        window_data = data.iloc[:, i:i + window_size]
        window_mean = window_data.mean(axis=1) 
        moving_average_data[f'{index}'] = window_mean
        index += 1

    return moving_average_data

# %% [markdown]
# ### ANCOVA

# %%
def analyze_ancova_for_each_column(data, column_len: int, between: str, covar: list):
    significant_0_05 = [] # p<0.5
    significant_0_01 = [] # p<0.1
    significant_0_001 = [] # p<0.01
    p_values = []
    
    # 각 열(1에서 27까지)에 대한 ANCOVA 실행
    for column_number in range(1, column_len):
        ancova_result = ancova(data=data, dv=f'{column_number}', between=between, covar=covar)
        p_value = ancova_result['p-unc'][0]
        p_values.append((int(column_number), ancova_result['p-unc'][0]))

        print(f"Column {column_number} ANCOVA Results:")
        print(ancova_result)
        print()

        if p_value < 0.05:
            significant_0_05.append(column_number)
        if p_value < 0.01:
            significant_0_01.append(column_number)
        if p_value < 0.001:
            significant_0_001.append(column_number)

    return p_values, significant_0_05, significant_0_01, significant_0_001

# %% [markdown]
# ### similairty line graph

# %%
def draw_similarity_line_graph(data, target_columns: list, significant_list: list, window_size: int, seed_word: str, filename: str, ax=None):
    # 이동 평균 계산
    low = data.loc[data['group_PA'] == 1].iloc[:, :len(target_columns)]
    high = data.loc[data['group_PA'] == 2].iloc[:, :len(target_columns)]

    low_datas = low.mean()
    high_datas = high.mean()

    plt.figure(figsize=(8, 6))
    plt.plot(high_datas, marker='.', color='#7a58a3', linestyle='-', label='High')
    plt.plot(low_datas, marker='.', color='#73a69e', linestyle='--', label='low')

    # 유의한 점 표시
    for point in significant_list:
        plt.axvspan(point - 1.5, point - 0.5, alpha=0.2, color='gray')
        plt.text(point-1.2, high_datas[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
        
    plt.title(f'Seed word: {seed_word}', fontsize=15, weight='bold')
    plt.ylim(0, 0.2)
    plt.legend(loc='upper right')

    plt.xticks(range(0, len(low_datas), window_size))

    filepath =  (f'\\{graph_image_dir}\\{filename}' if os_system == 'Windows' else f'/{graph_image_dir}/{filename}')
    plt.savefig(filepath, dpi=300)

    # plt.show()

# %% [markdown]
# ### similairty smoothing graph

# %%
def draw_similarity_smoothing_graph(data, target_columns: list, significant_list: list, window_size: int, seed_word:str, filename: str):
    # 이동 평균 계산
    low = data.loc[data['group_PA'] == 1].iloc[:, :len(target_columns)]
    high = data.loc[data['group_PA'] == 2].iloc[:, :len(target_columns)]
    low_smoothed_values = low.mean().rolling(window=window_size).mean()
    high_smoothed_values = high.mean().rolling(window=window_size).mean()

    plt.figure(figsize=(8, 6))

    # 신뢰구간 
    confidence_interval = 1.96  # 95% 신뢰구간

    low_sem = low.sem()
    high_sem = high.sem()

    lower_bound_low = (low_smoothed_values - confidence_interval * low_sem).dropna().reset_index(drop=True)
    upper_bound_low = (low_smoothed_values + confidence_interval * low_sem).dropna().reset_index(drop=True)
    lower_bound_high = (high_smoothed_values - confidence_interval * high_sem).dropna().reset_index(drop=True)
    upper_bound_high = (high_smoothed_values + confidence_interval * high_sem).dropna().reset_index(drop=True)

    # x축 1부터 시작하게 하기 위해 인덱스 변환
    lower_bound_low.index = range(1, len(lower_bound_low) + 1)
    upper_bound_low.index = range(1, len(upper_bound_low) + 1)
    lower_bound_high.index = range(1, len(lower_bound_high) + 1)
    upper_bound_high.index = range(1, len(upper_bound_high) + 1)

    plt.fill_between(range(len(lower_bound_low)), lower_bound_low, upper_bound_low, color='#73a69e', alpha=0.3)
    plt.fill_between(range(len(lower_bound_high)), lower_bound_high, upper_bound_high, color='#7a58a3', alpha=0.3)

    # 스무딩 그래프
    plt.plot(high_smoothed_values.dropna().reset_index(drop=True), color='#7a58a3', linestyle='-', label='High')
    plt.plot(low_smoothed_values.dropna().reset_index(drop=True), color='#73a69e', linestyle='--', label='Low')

    # 유의한 점 표시
    for point in significant_list:
        plt.axvspan(point - 1.5, point - 0.5, alpha=0.2, color='gray')
        plt.text(point-1.2, high_smoothed_values[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')

    plt.title(f'Seed word: {seed_word}', fontsize=15, weight='bold')
    plt.ylim(0, 0.2)
    plt.legend(loc='upper right')

    plt.xticks(range(0, len(low_smoothed_values), window_size))

    filepath =  (f'\\{graph_image_dir}\\{filename}' if os_system == 'Windows' else f'/{graph_image_dir}/{filename}')
    plt.savefig(filepath, dpi=300)

    # plt.show()

# %% [markdown]
# ## multiple comparison

# %%
def benjamini_hochberg_correction(p_values, alpha=0.05):
    fdr_significant_0_05 = [] # p<0.5
    fdr_significant_0_01 = [] # p<0.1
    fdr_significant_0_001 = [] # p<0.01

    p_values = [item[1] for item in p_values]
    adjusted_p_values = multipletests(p_values, method='fdr_bh', alpha=alpha)[1]

    for i, p_value in enumerate(adjusted_p_values):
        if p_value < 0.05:
            fdr_significant_0_05.append(i+1)
        if p_value < 0.01:
            fdr_significant_0_01.append(i+1)
        if p_value < 0.001:
            fdr_significant_0_001.append(i+1)

    return adjusted_p_values, fdr_significant_0_05, fdr_significant_0_01, fdr_significant_0_001

# %% [markdown]
# # main code

# %%
seed_words = ['key', 'money', 'friend']
target_words = ['money', 'friend']

# %%
similarity_datas = {
    'key_money': similarity_data.iloc[:, 1:31],
    'money_money': similarity_data.iloc[:, 31:61],
    'friend_money': similarity_data.iloc[:, 61:91],

    'key_friend': similarity_data.iloc[:, 91:121],
    'money_friend': similarity_data.iloc[:, 121:151],
    'friend_friend': similarity_data.iloc[:, 151:181]
}

# %%
window_size=4
moving_size=1

for i, seed in enumerate(seed_words): 
    for j, target in enumerate(target_words): 
        print(f'Seed word: {seed}, Target: {target}')
        data = similarity_datas[f'{seed}_{target}']

        moving_average_df = calculate_moving_average(data=data,
                                                     window_size=window_size,
                                                     moving_size=moving_size)
        # ancova 분석을 위해 데이터 연결
        merged_df = pd.concat([moving_average_df, survey_data], axis=1)

        target_columns = moving_average_df.columns
        # ancova 분석 -> 결과: p값들, significant한 index정보
        p_values, significant_0_05, significant_0_01, significant_0_001 = analyze_ancova_for_each_column(data=merged_df,
                                                                                                         column_len=len(target_columns),
                                                                                                         between='group_PA',
                                                                                                         covar=['age', 'sex'])

        # line graph, smoothing graph 그리기
        draw_similarity_line_graph(data=merged_df,
                                   target_columns=target_columns,
                                   significant_list=significant_0_05,
                                   window_size=window_size,
                                   seed_word=seed,
                                   filename=f'line_graph_{seed}_{target}.png')
        draw_similarity_smoothing_graph(data=merged_df,
                                        target_columns=target_columns,
                                        significant_list=significant_0_05,
                                        window_size=window_size,
                                        seed_word=seed,
                                        filename=f'smoothing_graph_{seed}_{target}.png')

        # multiple comparison 보정
        adjusted_p_values, fdr_significant_0_05, fdr_significant_0_01, fdr_significant_0_001 = benjamini_hochberg_correction(p_values=p_values, alpha=0.05)
        print(f'보정 전 p-values: {[item[1] for item in p_values]}')
        print(f'보정 후 p-values: {adjusted_p_values}')
        print()
        print()


plt.show()
# Out:
# Seed word: key, Target: money
# Column 1 ANCOVA Results:
#      Source            SS   DF         F     p-unc       np2
# 0  group_PA  7.062543e-04    1  0.543691  0.461746  0.002632
# 1       age  1.960032e-04    1  0.150888  0.698090  0.000732
# 2       sex  3.023557e-07    1  0.000233  0.987842  0.000001
# 3  Residual  2.675940e-01  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.004451    1  1.295697  0.256323  0.006250
# 1       age  0.003193    1  0.929479  0.336129  0.004492
# 2       sex  0.002394    1  0.696818  0.404822  0.003371
# 3  Residual  0.707698  206       NaN       NaN       NaN
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.007504    1  1.672949  0.197312  0.008056
# 1       age  0.006615    1  1.474888  0.225966  0.007109
# 2       sex  0.004549    1  1.014121  0.315099  0.004899
# 3  Residual  0.923965  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.008159    1  1.562162  0.212767  0.007526
# 1       age  0.004097    1  0.784403  0.376831  0.003793
# 2       sex  0.007268    1  1.391493  0.239514  0.006709
# 3  Residual  1.075914  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.004182    1  0.905971  0.342301  0.004379
# 1       age  0.003867    1  0.837668  0.361135  0.004050
# 2       sex  0.006407    1  1.387827  0.240131  0.006692
# 3  Residual  0.951010  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000193    1  0.065095  0.798871  0.000316
# 1       age  0.001244    1  0.418742  0.518286  0.002029
# 2       sex  0.002263    1  0.761641  0.383832  0.003684
# 3  Residual  0.612050  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.
ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001306    1  0.349359  0.555124  0.001693
# 1       age  0.000145    1  0.038853  0.843935  0.000189
# 2       sex  0.001206    1  0.322596  0.570670  0.001564
# 3  Residual  0.769808  206       NaN       NaN       NaN
#
# Column 21 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000125    1  0.033639  0.854658  0.000163
# 1       age  0.001431    1  0.385317  0.535458  0.001867
# 2       sex  0.000887    1  0.238879  0.625537  0.001158
# 3  Residual  0.764957  206       NaN       NaN       NaN
#
# Column 22 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000035    1  0.011566  0.914463  0.000056
# 1       age  0.000568    1  0.185498  0.667140  0.000900
# 2       sex  0.002959    1  0.966368  0.326741  0.004669
# 3  Residual  0.630844  206       NaN       NaN       NaN
#
# Column 23 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000362    1  0.149507  0.699406  0.000725
# 1       age  0.000005    1  0.001864  0.965601  0.000009
# 2       sex  0.000356    1  0.146948  0.701864  0.000713
# 3  Residual  0.498445  206       NaN       NaN       NaN
#
# Column 24 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000098    1  0.032190  0.857788  0.000156
# 1       age  0.000012    1  0.003921  0.950130  0.000019
# 2       sex  0.000111    1  0.036613  0.848444  0.000178
# 3  Residual  0.626089  206       NaN       NaN       NaN
#
# Column 25 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001803    1  0.498505  0.480955  0.002414
# 1       age  0.000149    1  0.041117  0.839512  0.000200
# 2       sex  0.001312    1  0.362777  0.547630  0.001758
# 3  Residual  0.745205  206       NaN       NaN       NaN
#
# Column 26 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001369    1  0.356756  0.550970  0.001729
# 1       age  0.000009    1  0.002313  0.961689  0.000011
# 2       sex  0.000032    1  0.008394  0.927090  0.000041
# 3  Residual  0.790549  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.4617461412733497, 0.2563228780910808, 0.197312429530377, 0.2127669595913734, 0.34230121321955587, 0.7988709999290147, 0.9822134327975061, 0.4243876478225874, 0.3797102392834273, 0.4930173140971147, 0.5251584394006839, 0.6187220835474241, 0.4092376319060129, 0.8054394528996379, 0.96562945018468, 0.707498247595584, 0.31149727309253217, 0.5425879130319793, 0.701643949774624, 0.5551241448139044, 0.8546577144050924, 0.9144626034159249, 0.6994057906287816, 0.8577879837695184, 0.48095544478256225, 0.5509696084226761]
# 보정 후 p-values: [0.96221518 0.96221518 0.96221518 0.96221518 0.96221518 0.96967337
#  0.98221343 0.96221518 0.96221518 0.96221518 0.96221518 0.9681555
#  0.96221518 0.96967337 0.98221343 0.9681555  0.96221518 0.96221518
#  0.9681555  0.96221518 0.96967337 0.98221343 0.9681555  0.96967337
#  0.96221518 0.96221518]
#
#
# Seed word: key, Target: friend
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001123    1  0.241854  0.623394  0.001173
# 1       age  0.002248    1  0.484050  0.487378  0.002344
# 2       sex  0.003876    1  0.834417  0.362066  0.004034
# 3  Residual  0.956904  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000195    1  0.027237  0.869077  0.000132
# 1       age  0.010186    1  1.425116  0.233936  0.006871
# 2       sex  0.024447    1  3.420283  0.065833  0.016332
# 3  Residual  1.472402  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002693    1  0.312480  0.576770  0.001515
# 1       age  0.009079    1  1.053592  0.305885  0.005088
# 2       sex  0.013825    1  1.604229  0.206735  0.007727
# 3  Residual  1.775223  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0
ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000115    1  0.019059  0.890333  0.000093
# 1       age  0.009567    1  1.579324  0.210281  0.007608
# 2       sex  0.003983    1  0.657559  0.418359  0.003182
# 3  Residual  1.247881  206       NaN       NaN       NaN
#
# Column 18 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000945    1  0.176929  0.674464  0.000858
# 1       age  0.002289    1  0.428534  0.513439  0.002076
# 2       sex  0.007147    1  1.337878  0.248748  0.006453
# 3  Residual  1.100411  206       NaN       NaN       NaN
#
# Column 19 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000054    1  0.009345  0.923084  0.000045
# 1       age  0.002547    1  0.439866  0.507929  0.002131
# 2       sex  0.016556    1  2.858897  0.092382  0.013688
# 3  Residual  1.192932  206       NaN       NaN       NaN
#
# Column 20 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000009    1  0.001426  0.969916  0.000007
# 1       age  0.000021    1  0.003479  0.953022  0.000017
# 2       sex  0.006180    1  1.014604  0.314984  0.004901
# 3  Residual  1.254849  206       NaN       NaN       NaN
#
# Column 21 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000165    1  0.027164  0.869250  0.000132
# 1       age  0.000118    1  0.019527  0.889003  0.000095
# 2       sex  0.001739    1  0.286719  0.592909  0.001390
# 3  Residual  1.249759  206       NaN       NaN       NaN
#
# Column 22 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000687    1  0.120322  0.729040  0.000584
# 1       age  0.000567    1  0.099327  0.752958  0.000482
# 2       sex  0.000012    1  0.002158  0.962997  0.000010
# 3  Residual  1.175877  206       NaN       NaN       NaN
#
# Column 23 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000385    1  0.078417  0.779735  0.000381
# 1       age  0.000010    1  0.002103  0.963468  0.000010
# 2       sex  0.003518    1  0.717260  0.398027  0.003470
# 3  Residual  1.010334  206       NaN       NaN       NaN
#
# Column 24 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000345    1  0.070973  0.790192  0.000344
# 1       age  0.000069    1  0.014197  0.905270  0.000069
# 2       sex  0.002500    1  0.514001  0.474224  0.002489
# 3  Residual  1.001868  206       NaN       NaN       NaN
#
# Column 25 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000162    1  0.032794  0.856474  0.000159
# 1       age  0.001897    1  0.383042  0.536663  0.001856
# 2       sex  0.000793    1  0.160085  0.689493  0.000777
# 3  Residual  1.019962  206       NaN       NaN       NaN
#
# Column 26 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000322    1  0.059700  0.807214  0.000290
# 1       age  0.000881    1  0.163233  0.686617  0.000792
# 2       sex  0.000087    1  0.016178  0.898911  0.000079
# 3  Residual  1.111596  206       NaN       NaN       NaN
#
# 보정 전 p-values: [0.6233935191592397, 0.8690773155994208, 0.5767696629455266, 0.6161922489792506, 0.3479897386172571, 0.432746935390814, 0.7387235869416394, 0.9361739608201598, 0.40420884750775565, 0.603683528639959, 0.6644501576532547, 0.2715594564822964, 0.3087067081202076, 0.8070179595937104, 0.63661882939151, 0.9229132631787308, 0.890332858721286, 0.674463972170549, 0.9230844989370335, 0.969915713499924, 0.8692501444711677, 0.7290397861303559, 0.7797354309884345, 0.7901922916172647, 0.8564735104318151, 0.8072142335929059]
# 보정 후 p-values: [0.96991571 0.96991571 0.96991571 0.96991571 0.96991571 0.96991571
#  0.96991571 0.96991571 0.96991571 0.96991571 0.96991571 0.96991571
#  0.96991571 0.96991571 0.96991571 0.96991571 0.96991571 0.96991571
#  0.96991571 0.96991571 0.96991571 0.96991571 0.96991571 0.96991571
#  0.96991571 0.96991571]
#
#
# Seed word: money, Target: money
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0
# 보정 전 p-values: [0.5299463319360213, 0.5931626601396249, 0.48193730635115006, 0.579866490001326, 0.8700642492828852, 0.7103167557644167, 0.35661997121868927, 0.8932096702343473, 0.7950225856508922, 0.8337610302981824, 0.9743715278396528, 0.5455677805599081, 0.431566263408389, 0.21980481390887754, 0.12675951870548824, 0.3681306161288196, 0.24155209678676628, 0.5632189734912036, 0.9767068933322126, 0.3746736351913984, 0.35739216669232154, 0.38131230909454317, 0.33722256815060836, 0.44871274945493544, 0.42085592783950654, 0.5118228100932423]
# 보정 후 p-values: [0.81169627 0.81169627 0.81169627 0.81169627 0.96764381 0.92341178
#  0.81169627 0.96764381 0.96764381 0.96764381 0.97670689 0.81169627
#  0.81169627 0.81169627 0.81169627 0.81169627 0.81169627 0.81169627
#  0.97670689 0.81169627 0.81169627 0.81169627 0.81169627 0.81169627
#  0.81169627 0.81169627]
#
#
# Seed word: money, Target: friend
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002647    1  0.980344  0.323275  0.004736
# 1       age  0.000711    1  0.263470  0.608296  0.001277
# 2       sex  0.000227    1  0.083944  0.772314  0.000407
# 3  Residual  0.556224  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001743    1  0.466702  0.495276  0.002260
# 1       age  0.001259    1  0.337083  0.562152  0.001634
# 2       sex  0.000242    1  0.064771  0.799363  0.000314
# 3  Residual  0.769151  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000663    1  0.175611  0.675609  0.000852
# 1       age  0.000663    1  0.175603  0.675616  0.000852
# 2       sex  0.000901    1  0.238679  0.625682  0.001157
# 3  Residual  0.777922  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000764    1  0.190014  0.663362  0.000922
# 1       age  0.000305    1  0.075763  0.783399  0.000368
# 2       sex  0.005692    1  1.415436  0.235525  0.006824
# 3  Residual  0.828446  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.009811    1  2.308633  0.130190  0.011083
# 1       age  0.005731    1  1.348498  0.246885  0.006504
# 2       sex  0.018667    1  4.392508  0.037319  0.020878
# 3  Residual  0.875427  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.013781    1  2.675958  0.103401  0.012824
# 1       age  0.028045    1  5.445732  0.020580  0.025755
# 2       sex  0.007836    1  1.521621  0.218780  0.007332
# 3  Residual  1.060878  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.019688    1  3.529610  0.061694  0.016845
# 1       age  0.055115    1  9.881075  0.001916  0.045771
# 2       sex  0.007030    1  1.260351  0.262891  0.006081
# 3  Residual  1.149043  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF          F     p-unc       np2
# 0  group_PA  0.019593    1   3.252304  0.072784  0.015543
# 1       age  0.065763    1  10.916466  0.001124  0.050326
# 2       sex  0.002138    1   0.354901  0.552006  0.001720
# 3  Residual  1.240994  206        NaN       NaN       NaN
#
# Column 9 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.006533    1  1.247863  0.265262  0.006021
# 1       age  0.030910    1  5.904372  0.015960  0.027863
# 2       sex  0.000319    1  0.060924  0.805287  0.000296
# 3  Residual  1.078414  206       NaN       NaN       NaN
#
# Column 10 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002898    1  0.599718  0.439574  0.002903
# 1       age  0.004942    1  1.022459  0.313123  0.004939
# 2       sex  0.000143    1  0.029637  0.863485  0.000144
# 3  Residual  0.995615  206       NaN       NaN       NaN
#
# Column 11 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.
ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002906    1  0.631936  0.427561  0.003058
# 1       age  0.000010    1  0.002099  0.963504  0.000010
# 2       sex  0.016304    1  3.545583  0.061113  0.016920
# 3  Residual  0.947284  206       NaN       NaN       NaN
#
# Column 25 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001557    1  0.331586  0.565355  0.001607
# 1       age  0.000977    1  0.207978  0.648837  0.001009
# 2       sex  0.014753    1  3.140914  0.077829  0.015018
# 3  Residual  0.967588  206       NaN       NaN       NaN
#
# Column 26 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003729    1  0.752895  0.386571  0.003642
# 1       age  0.002400    1  0.484531  0.487162  0.002347
# 2       sex  0.004090    1  0.825682  0.364586  0.003992
# 3  Residual  1.020315  206       NaN       NaN       NaN
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/2488767143.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_datas[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/3942423431.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_smoothed_values[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# 보정 전 p-values: [0.3232753791865671, 0.4952760334389166, 0.6756092570373546, 0.6633616909199849, 0.130190433155119, 0.10340097175984644, 0.06169432485553194, 0.07278430012361627, 0.26526227956540355, 0.43957352335832744, 0.9098268415379156, 0.6354510177762781, 0.5635743600727899, 0.4471168799151828, 0.8189982102846534, 0.4261336104095613, 0.0598614067631266, 0.013720415401327273, 0.042867628398997625, 0.018389491390870438, 0.09229181004796645, 0.23236732730182527, 0.2611054524826165, 0.42756092102064414, 0.5653553743539541, 0.38657087839534265]
# 보정 후 p-values: [0.64583549 0.67774615 0.73191003 0.73191003 0.3761057  0.33605316
#  0.31539863 0.31539863 0.57473494 0.64583549 0.90982684 0.73191003
#  0.6999638  0.64583549 0.85175814 0.64583549 0.31539863 0.23906339
#  0.31539863 0.23906339 0.33605316 0.57473494 0.57473494 0.64583549
#  0.6999638  0.64583549]
#
#
# Seed word: friend, Target: money
# Column 1 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000566    1  0.130788  0.717987  0.000634
# 1       age  0.000956    1  0.221193  0.638630  0.001073
# 2       sex  0.000326    1  0.075297  0.784050  0.000365
# 3  Residual  0.890760  206       NaN       NaN       NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000240    1  0.061342  0.804634  0.000298
# 1       age  0.000036    1  0.009081  0.924172  0.000044
# 2       sex  0.001231    1  0.314736  0.575398  0.001526
# 3  Residual  0.805799  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003999    1  1.239281  0.266907  0.005980
# 1       age  0.000088    1  0.027145  0.869297  0.000132
# 2       sex  0.007824    1  2.424667  0.120974  0.011633
# 3  Residual  0.664767  206       NaN       NaN       NaN
#
# Column 4 ANCOVA Results:
#      Source            SS   DF         F     p-unc       np2
# 0  group_PA  3.376016e-03    1  0.984087  0.322356  0.004754
# 1       age  7.566899e-07    1  0.000221  0.988165  0.000001
# 2       sex  1.771359e-02    1  5.163395  0.024100  0.024452
# 3  Residual  7.067054e-01  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.008335    1  2.488540  0.116212  0.011936
# 1       age  0.000662    1  0.197548  0.657174  0.000958
# 2       sex  0.016983    1  5.070592  0.025390  0.024023
# 3  Residual  0.689946  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.007363    1  2.477126  0.117048  0.011882
# 1       age  0.001000    1  0.336250  0.562636  0.001630
# 2       sex  0.014046    1  4.725292  0.030862  0.022424
# 3  Residual  0.612345  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003977    1  1.604215  0.206737  0.007727
# 1       age  0.000005    1  0.001949  0.964830  0.000009
# 2       sex  0.003641    1  1.468878  0.226911  0.007080
# 3  Residual  0.510685  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.014300    1  4.316044  0.038994  0.020522
# 1       age  0.000294    1  0.088848  0.765948  0.000431
# 2       sex  0.002758    1  0.832390  0.362649  0.004024
# 3  Residual  0.682504  206       NaN       NaN       NaN
#
# Column 9 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.018743    1  4.489965  0.035292  0.021331
# 1       age  0.000521    1  0.124719  0.724333  0.000605
# 2       sex  0.002903    1  0.695326  0.405325  0.003364
# 3  Residual  0.859927  206       NaN       NaN       NaN
#
# Column 10 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.017596    1  4.716065  0.031024  0.022381
# 1       age  0.000133    1  0.035721  0.850278  0.000173
# 2       sex  0.008623    1  2.311284  0.129971  0.011095
# 3  Residual  0.768584  206       NaN       NaN       NaN
#
# Column 11 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.008455    1  2.540475  0.112502  0.012241
# 1       age  0.001140    1  0.342408  0.559086  0.001667
# 2       sex  0.008344    1  2.507134  0.114873  0.012082
# 3  Residual  0.682272  205       NaN       NaN       NaN
#
# Column 12 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001089    1  0.374962  0.540991  0.001826
# 1       age  0.001423    1  0.489903  0.484764  0.002384
# 2       sex  0.005307    1  1.826791  0.177997  0.008832
# 3  Residual  0.595577  205       NaN       NaN       NaN
#
# Column 13 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.002652    1  0.978958  0.323617  0.004730
# 1       age  0.000692    1  0.255426  0.613821  0.001238
# 2       sex  0.000689    1  0.254386  0.614543  0.001233
# 3  Residual  0.558107  206       NaN       NaN       NaN
#
# Column 14 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000801    1  0.308073  0.579467  0.001493
# 1       age  0.000712    1  0.273851  0.601323  0.001328
# 2       sex  0.000218    1  0.083726  0.772601  0.000406
# 3  Residual  0.535609  206       NaN       NaN       NaN
#
# Column 15 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000889    1  0.312086  0.577010  0.001513
# 1       age  0.002054    1  0.721290  0.396707  0.003489
# 2       sex  0.000075    1  0.026300  0.871328  0.000128
# 3  Residual  0.586620  206       NaN       NaN       NaN
#
# Column 16 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001996    1  0.698606  0.404221  0.003380
# 1       age  0.000290    1  0.101450  0.750419  0.000492
# 2       sex  0.000074    1  0.025861  0.872399  0.000126
# 3  Residual  0.588470  206       NaN       NaN       NaN
#
# Column 17 ANCOVA Results:
#      Source            SS   DF         F     p-unc           np2
# 0  group_PA  1.508367e-04    1  0.049512  0.824135  2.402917e-04
# 1       age  1.565444e-03    1  0.513856  0.474287  2.488238e-03
# 2       sex  3.344132e-07    1  0.000110  0.991651  5.328677e-07
# 3  Residual  6.275724e-01  206       NaN       NaN           NaN
#
# Column 18 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000278    1  0.083081  0.773454  0.000403
# 1       age  0.001879    1  0.562397  0.454152  0.002723
# 2       sex  0.000513    1  0.153661  0.695466  0.000745
# 3  Residual  0.688294  206       NaN       NaN       NaN
#
# Column 19 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000035    1  0.007092  0.932966  0.000034
# 1       age  0.000552    1  0.113215  0.736855  0.000549
# 2       sex  0.000048    1  0.009791  0.921273  0.000048
# 3  Residual  1.003717  206       NaN       NaN       NaN
#
# Column 20 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000026    1  0.004773  0.944987  0.000023
# 1       age  0.003193    1  0.581621  0.446554  0.002829
# 2       sex  0.000173    1  0.031604  0.859076  0.000154
# 3  Residual  1.125249  205       NaN       NaN       NaN
#
# Column 21 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000079    1  0.016003  0.899458  0.000078
# 1       age  0.001531    1  0.311094  0.577615  0.001508
# 2       sex  0.000036    1  0.007282  0.932080  0.000035
# 3  Residual  1.013661  206       NaN       NaN       NaN
#
# Column 22 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.005818    1  1.260507  0.262862  0.006082
# 1       age  0.001925    1  0.417179  0.519067  0.002021
# 2       sex  0.000647    1  0.140083  0.708584  0.000680
# 3  Residual  0.950741  206       NaN       NaN       NaN
#
# Column 23 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003056    1  0.934823  0.334747  0.004517
# 1       age  0.000100    1  0.030440  0.861667  0.000148
# 2       sex  0.003748    1  1.146602  0.285514  0.005535
# 3  Residual  0.673415  206       NaN       NaN       NaN
#
# Column 24 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.005381    1  1.656023  0.199585  0.007975
# 1       age  0.002027    1  0.623936  0.430497  0.003020
# 2       sex  0.003614    1  1.112290  0.292820  0.005370
# 3  Residual  0.669385  206       NaN       NaN       NaN
#
# Column 25 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.014564    1  3.363167  0.068112  0.016064
# 1       age  0.003191    1  0.736957  0.391635  0.003565
# 2       sex  0.006408    1  1.479693  0.225214  0.007132
# 3  Residual  0.892082  206       NaN       NaN       NaN
#
# Column 26 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.016474    1  4.438656  0.036344  0.021092
# 1       age  0.005701    1  1.536022  0.216621  0.007401
# 2       sex  0.000257    1  0.069164  0.792820  0.000336
# 3  Residual  0.764544  206       NaN       NaN       NaN
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/2488767143.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_datas[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/3942423431.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_smoothed_values[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# 보정 전 p-values: [0.7179871458487629, 0.8046337556369652, 0.2669068730787005, 0.3223557390253994, 0.11621239883767889, 0.11704771724086904, 0.2067370717808198, 0.03899431957378167, 0.035292137376872715, 0.031024451980296925, 0.1125020305305913, 0.5409906506666399, 0.3236169229313931, 0.5794671120639903, 0.5770099757494773, 0.40422074185535706, 0.8241350903468437, 0.7734542811891074, 0.9329661792272572, 0.9449867143925943, 0.8994583781432487, 0.26286204764219984, 0.33474657840841027, 0.19958538294190883, 0.0681124660360889, 0.036344118379714005]
# 보정 후 p-values: [0.93163097 0.93163097 0.57829823 0.5802274  0.38040508 0.38040508
#  0.53751639 0.25346308 0.25346308 0.25346308 0.38040508 0.792955
#  0.5802274  0.792955   0.792955   0.65685871 0.93163097 0.93163097
#  0.94498671 0.94498671 0.94498671 0.57829823 0.5802274  0.53751639
#  0.35418482 0.25346308]
#
#
# Seed word: friend, Target: friend
# Column 1 ANCOVA Results:
#      Source            SS   DF             F     p-unc           np2
# 0  group_PA  1.031511e-02    1  8.057376e-01  0.370431  3.896109e-03
# 1       age  5.157869e-09    1  4.028935e-07  0.999494  1.955794e-09
# 2       sex  1.771253e-02    1  1.383568e+00  0.240852  6.671541e-03
# 3  Residual  2.637225e+00  206           NaN       NaN           NaN
#
# Column 2 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.010354    1  0.883996  0.348211  0.004273
# 1       age  0.003478    1  0.296896  0.586424  0.001439
# 2       sex  0.026806    1  2.288606  0.131860  0.010988
# 3  Residual  2.412874  206       NaN       NaN       NaN
#
# Column 3 ANCOVA Results:
#      Source            SS   DF         F     p-unc           np2
# 0  group_PA  6.522559e-03    1  0.825091  0.364757  3.989319e-03
# 1       age  1.316636e-08    1  0.000002  0.998972  8.085044e-09
# 2       sex  2.881548e-02    1  3.645104  0.057624  1.738702e-02
# 3  Residual  1.628483e+00  206       NaN       NaN           NaN
#
# Column 4 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001545    1  0.235873  0.627719  0.001144
# 1       age  0.000699    1  0.106713  0.744250  0.000518
# 2       sex  0.021407    1  3.268212  0.072093  0.015617
# 3  Residual  1.349322  206       NaN       NaN       NaN
#
# Column 5 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001747    1  0.270182  0.603768  0.001310
# 1       age  0.000647    1  0.100113  0.752014  0.000486
# 2       sex  0.024316    1  3.760129  0.053854  0.017926
# 3  Residual  1.332176  206       NaN       NaN       NaN
#
# Column 6 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.004941    1  0.845641  0.358864  0.004088
# 1       age  0.007787    1  1.332757  0.249653  0.006428
# 2       sex  0.024696    1  4.226646  0.041055  0.020105
# 3  Residual  1.203663  206       NaN       NaN       NaN
#
# Column 7 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.009567    1  1.663010  0.198643  0.008008
# 1       age  0.007669    1  1.333027  0.249605  0.006429
# 2       sex  0.015422    1  2.680615  0.103103  0.012846
# 3  Residual  1.185126  206       NaN       NaN       NaN
#
# Column 8 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.022076    1  4.473359  0.035629  0.021254
# 1       age  0.007447    1  1.509108  0.220677  0.007272
# 2       sex  0.013490    1  2.733563  0.099783  0.013096
# 3  Residual  1.016615  206       NaN       NaN       NaN
#
# Column 9 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.017376    1  3.734765  0.054662  0.017807
# 1       age  0.005635    1  1.211170  0.272385  0.005845
# 2       sex  0.010212    1  2.195073  0.139981  0.010543
# 3  Residual  0.958391  206       NaN       NaN       NaN
#
# Column 10 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.023387    1  4.874652  0.028357  0.023116
# 1       age  0.002184    1  0.455230  0.500618  0.002205
# 2       sex  0.009877    1  2.058696  0.152856  0.009895
# 3  Residual  0.988311  206       NaN       NaN       NaN
#
# Column 11 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.030306    1  7.330675  0.007351  0.034525
# 1       age  0.003216    1  0.777901  0.378817  0.003780
# 2       sex  0.024133    1  5.837350  0.016566  0.027687
# 3  Residual  0.847505  205       NaN       NaN       NaN
#
# Column 12 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.016903    1  3.936537  0.048582  0.018841
# 1       age  0.007084    1  1.649908  0.200421  0.007984
# 2       sex  0.010962    1  2.553029  0.111623  0.012301
# 3  Residual  0.880222  205       NaN       NaN       NaN
#
# Column 13 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.022000    1  4.769841  0.030092  0.022631
# 1       age  0.004541    1  0.984483  0.322259  0.004756
# 2       sex  0.009198    1  1.994137  0.159418  0.009587
# 3  Residual  0.950141  206       NaN       NaN       NaN
#
# Column 14 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.014591    1  3.026110  0.083428  0.014477
# 1       age  0.002665    1  0.552679  0.458072  0.002676
# 2       sex  0.006382    1  1.323491  0.251300  0.006384
# 3  Residual  0.993279  206       NaN       NaN       NaN
#
# Column 15 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003676    1  0.875102  0.350642  0.004230
# 1       age  0.001490    1  0.354620  0.552163  0.001718
# 2       sex  0.000803    1  0.191260  0.662328  0.000928
# 3  Residual  0.865313  206       NaN       NaN       NaN
#
# Column 16 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.004609    1  1.206600  0.273289  0.005823
# 1       age  0.000805    1  0.210725  0.646684  0.001022
# 2       sex  0.001102    1  0.288570  0.591718  0.001399
# 3  Residual  0.786896  206       NaN       NaN       NaN
#
# Column 17 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.003949    1  0.893466  0.345647  0.004318
# 1       age  0.000175    1  0.039621  0.842420  0.000192
# 2       sex  0.000692    1  0.156654  0.692665  0.000760
# 3  Residual  0.910388  206       NaN       NaN       NaN
#
# Column 18 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001265    1  0.313264  0.576292  0.001518
# 1       age  0.000595    1  0.147344  0.701483  0.000715
# 2       sex  0.000038    1  0.009487  0.922503  0.000046
# 3  Residual  0.831996  206       NaN       NaN       NaN
#
# Column 19 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000768    1  0.205442  0.650841  0.000996
# 1       age  0.000572    1  0.153086  0.696008  0.000743
# 2       sex  0.000016    1  0.004266  0.947990  0.000021
# 3  Residual  0.770285  206       NaN       NaN       NaN
#
# Column 20 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001050    1  0.269264  0.604386  0.001312
# 1       age  0.000160    1  0.040943  0.839850  0.000200
# 2       sex  0.000176    1  0.045153  0.831934  0.000220
# 3  Residual  0.799372  205       NaN       NaN       NaN
#
# Column 21 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.000202    1  0.061794  0.803930  0.000300
# 1       age  0.001641    1  0.503326  0.478844  0.002437
# 2       sex  0.000717    1  0.219981  0.639550  0.001067
# 3  Residual  0.671822  206       NaN       NaN       NaN
#
# Column 22 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.001255    1  0.382450  0.536978  0.001853
# 1       age  0.001752    1  0.534085  0.465725  0.002586
# 2       sex  0.000710    1  0.216493  0.642216  0.001050
# 3  Residual  0.675804  206       NaN       NaN       NaN
#
# Column 23 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.006689    1  1.863695  0.173688  0.008966
# 1       age  0.006592    1  1.836739  0.176818  0.008837
# 2       sex  0.000940    1  0.261918  0.609354  0.001270
# 3  Residual  0.739331  206       NaN       NaN       NaN
#
# Column 24 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.014488    1  3.666238  0.056911  0.017486
# 1       age  0.010616    1  2.686455  0.102731  0.012873
# 2       sex  0.002783    1  0.704279  0.402322  0.003407
# 3  Residual  0.814078  206       NaN       NaN       NaN
#
# Column 25 ANCOVA Results:
#      Source        SS   DF         F     p-unc       np2
# 0  group_PA  0.022732    1  5.165142  0.024077  0.024460
# 1       age  0.003736    1  0.848866  0.357951  0.004104
# 2       sex  0.001759    1  0.399581  0.528007  0.001936
# 3  Residual  0.906608  206       NaN       NaN       NaN
#
# Column 26 ANCOVA Results:
#      Source        SS   DF          F     p-unc       np2
# 0  group_PA  0.045138    1  10.219615  0.001608  0.047265
# 1       age  0.001531    1   0.346575  0.556703  0.001680
# 2       sex  0.002847    1   0.644494  0.423014  0.003119
# 3  Residual  0.909852  206        NaN       NaN       NaN
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/2488767143.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_datas[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# /var/folders/99/w9lwt31s6gzbvts3vs5x6myr0000gn/T/ipykernel_34175/3942423431.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(point-1.2, high_smoothed_values[point-1] + 0.003, '*', fontsize=10, color='#7a58a3')
# 보정 전 p-values: [0.37043131016438846, 0.3482107193930437, 0.36475720960705826, 0.6277191199403589, 0.6037675970621128, 0.3588639408041112, 0.19864342596745901, 0.03562904733961652, 0.05466242278499795, 0.028357280249790638, 0.007350926369339444, 0.048582104979868784, 0.03009166432503865, 0.0834278585358611, 0.35064209861569706, 0.27328879777572357, 0.34564717810272827, 0.5762919970094846, 0.6508406940394929, 0.6043855939793659, 0.8039303312983086, 0.5369780823468862, 0.17368797860038804, 0.056910770929795754, 0.024076556328008154, 0.0016083886249564628]
# 보정 후 p-values: [0.506906   0.506906   0.506906   0.67687432 0.67687432 0.506906
#  0.43039409 0.15439254 0.16440889 0.15439254 0.09556204 0.16440889
#  0.15439254 0.21691243 0.506906   0.506906   0.506906   0.67687432
#  0.67687432 0.67687432 0.80393033 0.67687432 0.41053522 0.16440889
#  0.15439254 0.0418181 ]

# %% [markdown]
# #### target별로 3개씩 그래프 합치기

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axes = plt.subplots(2, 3, figsize=(24, 12), constrained_layout=True)
plt.subplots_adjust(top=0, wspace=0, hspace=0)
ax = axes.flatten()

i = 0
for target in target_words:
    for seed in seed_words:
        # 이미지 불러오기
        img = mpimg.imread(graph_image_dir + f'/line_graph_{seed}_{target}.png')
        
        ax[i].imshow(img)
        ax[i].axis('off')

        if i in [0, 3]: 
            ax[i].text(0.03, 0.5, f'Similarity with "{target}"', transform=ax[i].transAxes, rotation=90, fontsize=15, color='black',  weight='bold', ha='center', va='center')

        i += 1
# 전체 그리드 이미지를 저장
filepath =  ( graph_image_dir + 'all_similarity_line_graph.png' )
plt.savefig(filepath, dpi=300)

# 화면에 그리드 이미지 표시
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(24, 12), constrained_layout=True)
plt.subplots_adjust(top=0, wspace=0, hspace=0)

ax = axes.flatten()

i = 0
for target in target_words:
    for seed in seed_words:
        # 이미지 불러오기
        img = mpimg.imread(graph_image_dir + f'/smoothing_graph_{seed}_{target}.png')
        
        ax[i].imshow(img)
        ax[i].axis('off')

        if i in [0, 3]: 
            ax[i].text(0.03, 0.5, f'Similarity with "{target}"', transform=ax[i].transAxes, rotation=90, fontsize=15, color='black',  weight='bold', ha='center', va='center')

        i += 1
# 전체 그리드 이미지를 저장
filepath =  ( graph_image_dir + 'all_smoothing_line_graph.png' )
plt.savefig(filepath, dpi=300)

# 화면에 그리드 이미지 표시
plt.show()
